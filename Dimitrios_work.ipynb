# %% [markdown]
# 5.Do more popular song tend to be shorter?
# 7.Which artist shows up the most in the data set?

# %%
import csv
import re
from functools import reduce
import numpy as np
import pandas as pd

# read in the dataset 
data = pd.read_csv("top50.csv")

# %%
# Isolate track name, length of the song in seconds, and popularity, then sort them by popularity in decending order 

data[['Track.Name','Length.','Popularity']].sort_values(['Popularity'], ascending=False)
# Out:
#                                            Track.Name  Length.  Popularity
# 9                                             bad guy      194          95
# 4                         Goodbyes (Feat. Young Thug)      175          94
# 10                                           Callaita      251          93
# 14           Money In The Grave (Drake ft. Rick Ross)      205          92
# 1                                               China      302          92
# 6                                              Ransom      131          92
# 36                                         Otro Trago      226          91
# 21                                             Panini      115          91
# 20                                Piece Of Your Heart      153          91
# 19                                        Truth Hurts      173          91
# 17      Sunflower - Spider-Man: Into the Spider-Verse      158          91
# ...

# %% [markdown]
# 5.Do more popular song tend to be shorter?
#
# As seen in the data, the length of the song does not contribute to the popularity of the song. The more popular songs do not follow any pattern of being shorter or longer therefore the popularity of the song does not hing on the length of the song.

# %%
# isolate artist name and track name, group them by artist name, counts the amount of songs that are made by 
# that certain artist, then sorts those values by track name value in decending order

data[['Artist.Name','Track.Name']].groupby(['Artist.Name']).count().sort_values(['Track.Name'], ascending=False)
# Out:
#                   Track.Name
# Artist.Name
# Ed Sheeran                 4
# Lil Nas X                  2
# Shawn Mendes               2
# Marshmello                 2
# Post Malone                2
# Sech                       2
# J Balvin                   2
# The Chainsmokers           2
# Billie Eilish              2
# Ariana Grande              2
# Taylor Swift               1
# Tones and I                1
# Lizzo                      1
# Sam Smith                  1
# ROSALÍA                    1
# Y2K                        1
# Nicky Jam                  1
# Martin Garrix              1
# Maluma                     1
# MEDUZA                     1
# Lunay                      1
# Ali Gatie                  1
# Lil Tecca                  1
# Anuel AA                   1
# Lewis Capaldi              1
# Lauv                       1
# Lady Gaga                  1
# Kygo                       1
# Khalid                     1
# Katy Perry                 1
# ...

# %% [markdown]
# 7.Which artist shows up the most in the data set?
#
# As seen in the data, the artists that show up the most are Ed Sheeran with 4 songs seconded by Lil Nas X, Shawn Mendez, Marshmello, Post Malone, Sech, J Balvin, The Chainsmokers, and Billie Eilish all with two songs. The rest of the artist on the list have 1 song.
